# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib as mpl
import matplotlib.pyplot as plt
import anndata as ad
from colorspacious import cspace_converter

# %%
adata = sc.read_h5ad("/vol/ExtraVol/Development_CellTypeAssigned.h5ad")

# %%
adata.uns['iroot'] = np.flatnonzero((adata.obs['stage'] == 'embryonic'))[0]

# %%
sc.tl.dpt(adata)

# %%
sc.pl.umap(adata, color=['leiden', 'cell_type', 'dpt_pseudotime'], legend_loc='on data')
# Out:
# /home/ubuntu/anaconda3/envs/scanpy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/ubuntu/anaconda3/envs/scanpy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.tl.paga(adata, groups='leiden')

# %%
sc.pl.paga(adata, threshold=0.03, show=False, color = ['dpt_pseudotime'])
# Out:
# <Axes: >

# %%
sc.pl.paga(adata, threshold=0.03, show=False, color = 'Adamdec1', use_raw=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sc.pl.paga(adata, threshold=0.03, show=False, color = 'Adamdec1', use_raw=False)
#
# File ~/anaconda3/envs/scanpy/lib/python3.11/site-packages/scanpy/plotting/_tools/paga.py:577, in paga(adata, threshold, color, layout, layout_kwds, init_pos, root, labels, single_component, solid_edges, dashed_edges, transitions, fontsize, fontweight, fontoutline, text_kwds, node_size_scale, node_size_power, edge_width_scale, min_edge_width, max_edge_width, arrowsize, title, left_margin, random_state, pos, normalize_to_color, cmap, cax, colorbar, cb_kwds, frameon, add_pos, export_to_gexf, use_raw, colors, groups, plot, show, save, ax)
#     575 if title[icolor] is not None:
#     576     axs[icolor].set_title(title[icolor])
# --> 577 sct = _paga_graph(
#     578     adata,
#     579     axs[icolor],
# ...

# %%
sc.pl.umap(adata, color=['Adamdec1'], use_raw=False)

# %%
sc.tl.draw_graph(adata, init_pos='paga')

# %%
sc.pl.draw_graph(adata, color=['cell_type', 'dpt_pseudotime'], legend_loc='on data')
# Out:
# /home/ubuntu/anaconda3/envs/scanpy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.draw_graph(adata, color=['Adamdec1', 'Igf2', 'Colec10', 'Sox6', 'Bmp5', 'Ogn', 'Ncam1','Jam2', 'Tcf4', 'Sparc'], 
                 legend_loc='on data', use_raw=False)

# %%
sc.pl.paga(adata, color=['Adamdec1', 'Igf2', 'Colec10', 'Sparc'], use_raw=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sc.pl.paga(adata, color=['Adamdec1', 'Igf2', 'Colec10', 'Sparc'], use_raw=False)
#
# File ~/anaconda3/envs/scanpy/lib/python3.11/site-packages/scanpy/plotting/_tools/paga.py:577, in paga(adata, threshold, color, layout, layout_kwds, init_pos, root, labels, single_component, solid_edges, dashed_edges, transitions, fontsize, fontweight, fontoutline, text_kwds, node_size_scale, node_size_power, edge_width_scale, min_edge_width, max_edge_width, arrowsize, title, left_margin, random_state, pos, normalize_to_color, cmap, cax, colorbar, cb_kwds, frameon, add_pos, export_to_gexf, use_raw, colors, groups, plot, show, save, ax)
#     575 if title[icolor] is not None:
#     576     axs[icolor].set_title(title[icolor])
# --> 577 sct = _paga_graph(
#     578     adata,
#     579     axs[icolor],
# ...
